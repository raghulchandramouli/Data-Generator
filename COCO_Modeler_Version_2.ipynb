# %% [markdown]
# <a href="https://colab.research.google.com/github/raghulchandramouli/Data-Generator/blob/main/COCO_Modeler_Version_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libs

# %%
import os
import requests
import zipfile
import cv2
import numpy as np
import random
from PIL import Image
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed

# %% [markdown]
# # Setting up `DIRS` & `PATHS`

# %%
DATASET_DIR = "dataset"  # Directory for COCO dataset & generated outputs
COCO_URL = "http://images.cocodataset.org/zips/test2017.zip"  # URL for COCO train dataset
COCO_ZIP = os.path.join(DATASET_DIR, "coco_test2017.zip")  # Path where the train zip will be saved
COCO_DIR = os.path.join(DATASET_DIR, "test2017")  # Folder name after extraction
MASK_DIR = os.path.join(DATASET_DIR, "masks")  # For generated dynamic masks
INPAINTED_DIR = os.path.join(DATASET_DIR, "inpainted")  # For inpainted images
NUM_IMAGES_TO_PROCESS = 5000

# %%
# Create Necessary dirs:
os.makedirs(DATASET_DIR, exist_ok=True)
os.makedirs(MASK_DIR, exist_ok=True)
os.makedirs(INPAINTED_DIR, exist_ok=True)

# %% [markdown]
# # Extract and Download COCO Train Dataset

# %%
if not os.path.exists(COCO_ZIP):
    print("Downloading COCO train dataset...")
    response = requests.get(COCO_URL, stream=True)
    with open(COCO_ZIP, "wb") as file:
        for chunk in response.iter_content(chunk_size=1024):
            file.write(chunk)

if not os.path.exists(COCO_DIR):
    print("Extracting COCO Train Dataset")
    with zipfile.ZipFile(COCO_ZIP, "r") as zip_ref:
        zip_ref.extractall(DATASET_DIR)
# Out:
# Downloading COCO train dataset...
# Extracting COCO Train Dataset

# %%
len(os.listdir(COCO_DIR))
# Out:
# 40670

# %% [markdown]
# # Dynamic Mask Generations Functions:

# %%
def generate_dynamic_mask(image_path, mask_path):
    """
    Generates a dynamic binary mask using random geometric shapes.
    Options include rectangle, circle, ellipse, bacteria-like shape, or a freeform (shapeless) blob.
    With a 30% chance, the mask will contain two shapes.

    Args:
      image_path (str): Path to the input image.
      mask_path (str): Path to save the generated mask.
    """

    image = cv2.imread(image_path)
    h, w, _ = image.shape
    mask = np.zeros((h, w), dtype=np.uint8)

    # List of shape types
    shape_types = ["rectangle", "circle", "ellipse", "bacteria", "freeform"]

    def draw_shape(shape, mask):
        if shape == "rectangle":
            x = random.randint(50, max(50, w - 150))
            y = random.randint(50, max(50, h - 150))
            mask_size = random.randint(50, min(150, w - x - 50, h - y - 50))
            cv2.rectangle(mask, (x, y), (x + mask_size, y + mask_size), 255, -1)


        elif shape == "circle":
            center_x = random.randint(50, w - 50)
            center_y = random.randint(50, h - 50)
            radius = random.randint(25, min(center_x, center_y, w - center_x, h - center_y, 75))
            cv2.circle(mask, (center_x, center_y), radius, 255, -1)


        elif shape == "ellipse":
            center_x = random.randint(50, w - 50)
            center_y = random.randint(50, h - 50)
            axis_length1 = random.randint(25, 75)
            axis_length2 = random.randint(25, 75)
            angle = random.randint(0, 360)
            cv2.ellipse(mask, (center_x, center_y), (axis_length1, axis_length2), angle, 0, 360, 255, -1)


        elif shape == "bacteria":
            # Bacteria-like shape: irregular polygon simulating a bacterial outline.
            center_x = random.randint(100, w - 100)
            center_y = random.randint(100, h - 100)
            base_radius = random.randint(30, 60)
            num_points = random.randint(8, 20)
            angles = np.linspace(0, 2 * np.pi, num_points, endpoint=False)
            points = []

            for angle in angles:

                noise = random.uniform(0.7, 1.3)
                r = base_radius * noise
                x_val = int(center_x + r * np.cos(angle))
                y_val = int(center_y + r * np.sin(angle))
                points.append([x_val, y_val])
            points = np.array(points, dtype=np.int32)
            cv2.fillPoly(mask, [points], 255)


        elif shape == "freeform":


            # Freeform shape: create an irregular blob around a central point,
            # ensuring the shape remains constrained within a limited area.
            margin = 100  # Ensure the center is not too close to the image boundaries.
            cx = random.randint(margin, w - margin)
            cy = random.randint(margin, h - margin)
            max_radius = random.randint(50, 100)  # Maximum extent of the freeform shape.
            num_points = random.randint(5, 15)
            points = []

            for _ in range(num_points):
                angle = random.random() * 2 * np.pi
                # The radius is randomly chosen so that the shape remains within a certain bound.
                r = random.uniform(10, max_radius)
                x_val = int(cx + r * np.cos(angle))
                y_val = int(cy + r * np.sin(angle))
                points.append([x_val, y_val])
            points = np.array(points, dtype=np.int32)

            # Use the convex hull to obtain a smooth, enclosed shape.
            hull = cv2.convexHull(points)
            cv2.fillPoly(mask, [hull], 255)
        return mask

    # Draw the first shape.
    first_shape = random.choice(shape_types)
    mask = draw_shape(first_shape, mask)

    # With a 30% chance, add a second shape on the same mask.
    if random.random() < 0.3:
        second_shape = random.choice(shape_types)
        mask = draw_shape(second_shape, mask)

    # Dilate the mask to smooth edges and expand the masked region.
    kernel = np.ones((15, 15), dtype=np.uint8)
    mask = cv2.dilate(mask, kernel, iterations=5)

    cv2.imwrite(mask_path, mask)

# %% [markdown]
# # Accelerated Mask Generation (Threading)

# %%
def generate_masks_concurrently(image_paths, mask_paths, num_workers=8):
  """
  Generates masks concurrently using a ThreadPoolExecutor.

  Args:
      image_paths (List[str]): List of paths to the input images.
      mask_paths (List[str]): List of paths to save the generated masks.
      num_workers (int, optional): The number of worker threads to use. Defaults to 8.
  """

  from concurrent.futures import ThreadPoolExecutor, as_completed
  with ThreadPoolExecutor(max_workers=num_workers) as executor:
    futures = [executor.submit(generate_dynamic_mask, img_path, mask_path) for img_path, mask_path in zip(image_paths, mask_paths)]
    for future in as_completed(futures):  # Corrected 'future' to 'futures'
      try:
        future.result()
      except Exception as e:
        print(f"Error: {e}")

# %% [markdown]
# # Batch Inpainting Functions with Dynamic Prompts

# %%
def inpaint_image_batch(original_paths, mask_paths, output_paths):
    """
    Batch inpainting using Stable Diffusion with a static text prompt.

    Args:
      original_paths (List[str]): List of paths to original images.
      mask_paths (List[str]): List of paths to corresponding mask images.
      output_paths (List[str]): List of paths to save the inpainted images.
    """

    originals = [Image.open(p).convert("RGB") for p in original_paths]
    masks = [Image.open(p).convert("L") for p in mask_paths]

    # Static prompt used for every image.
    prompt = "Fill the missing area with a natural, serene background"

    # Create a list of the same prompt to match the number of images.
    prompts = [prompt] * len(originals)

    # Perform batch inpainting.
    result = pipe(prompt=prompts, image=originals, mask_image=masks).images

    # Save each result to its corresponding output path.
    for img, out_path in zip(result, output_paths):
        img.save(out_path)

# %%
# !pip install xformers

# %%
from diffusers import StableDiffusionInpaintPipeline
import torch

pipe = StableDiffusionInpaintPipeline.from_pretrained(
    "stabilityai/stable-diffusion-2-inpainting",
    torch_dtype=torch.float16,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
pipe = pipe.to("cuda")
pipe.enable_xformers_memory_efficient_attention()
pipe.enable_attention_slicing()

# %%
# Get list of image filenames from COCO train folder
coco_images = sorted(os.listdir(COCO_DIR))
# Limit to the desired number of images
coco_images = coco_images[:min(len(coco_images), NUM_IMAGES_TO_PROCESS)]

# %%
BATCH_SIZE = 8

for i in tqdm(range(0, len(coco_images), BATCH_SIZE), desc="Processing Batches"):
    batch_imgs = coco_images[i: i + BATCH_SIZE]
    img_paths = [os.path.join(COCO_DIR, img) for img in batch_imgs]
    mask_paths = [os.path.join(MASK_DIR, img.replace(".jpg", "_mask.png")) for img in batch_imgs]
    inpainted_paths = [os.path.join(INPAINTED_DIR, img.replace(".jpg", "_inpainted.jpg")) for img in batch_imgs]

    # Generate masks concurrently.
    generate_masks_concurrently(img_paths, mask_paths, num_workers=8)

    # Inpaint images.
    inpaint_image_batch(img_paths, mask_paths, inpainted_paths)

print("Dynamic mask generation and inpainting complete.")
# Out:
# Processing Batches:   0%|          | 0/625 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Processing Batches:   0%|          | 1/625 [01:07<11:37:06, 67.03s/it]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Processing Batches:   0%|          | 2/625 [02:15<11:43:38, 67.77s/it]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Processing Batches:   0%|          | 3/625 [03:23<11:45:07, 68.02s/it]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Processing Batches:   1%|          | 4/625 [04:32<11:45:27, 68.16s/it]
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
len(os.listdir(MASK_DIR))
# Out:
# 112

# %%
# !zip -r masks_coco_v2.zip dataset/masks
# Out:
#   adding: dataset/masks/ (stored 0%)
#   adding: dataset/masks/000000000888_mask.png (deflated 93%)
#   adding: dataset/masks/000000000171_mask.png (deflated 46%)
#   adding: dataset/masks/000000000509_mask.png (deflated 58%)
#   adding: dataset/masks/000000000106_mask.png (deflated 75%)
#   adding: dataset/masks/000000000057_mask.png (deflated 90%)
#   adding: dataset/masks/000000000016_mask.png (deflated 65%)
#   adding: dataset/masks/000000001124_mask.png (deflated 56%)
#   adding: dataset/masks/000000000774_mask.png (deflated 49%)
#   adding: dataset/masks/000000000979_mask.png (deflated 93%)
#   adding: dataset/masks/000000000202_mask.png (deflated 56%)
#   adding: dataset/masks/000000001024_mask.png (deflated 5%)
#   adding: dataset/masks/000000000718_mask.png (deflated 54%)
#   adding: dataset/masks/000000000080_mask.png (deflated 60%)
#   adding: dataset/masks/000000000492_mask.png (deflated 55%)
#   adding: dataset/masks/000000001444_mask.png (deflated 58%)
#   adding: dataset/masks/000000000161_mask.png (deflated 42%)
#   adding: dataset/masks/000000000694_mask.png (deflated 43%)
#   adding: dataset/masks/000000000660_mask.png (deflated 69%)
#   adding: dataset/masks/000000000647_mask.png (deflated 71%)
#   adding: dataset/masks/000000001289_mask.png (deflated 74%)
#   adding: dataset/masks/000000000904_mask.png (deflated 19%)
#   adding: dataset/masks/000000001198_mask.png (deflated 60%)
#   adding: dataset/masks/000000000851_mask.png (deflated 64%)
#   adding: dataset/masks/000000001367_mask.png (deflated 50%)
#   adding: dataset/masks/000000000180_mask.png (deflated 69%)
#   adding: dataset/masks/000000001550_mask.png (deflated 40%)
#   adding: dataset/masks/000000001266_mask.png (deflated 81%)
#   adding: dataset/masks/000000000318_mask.png (deflated 50%)
#   adding: dataset/masks/000000001286_mask.png (deflated 92%)
#   adding: dataset/masks/000000000019_mask.png (deflated 48%)
#   adding: dataset/masks/000000000554_mask.png (deflated 72%)
#   adding: dataset/masks/000000000456_mask.png (deflated 62%)
#   adding: dataset/masks/000000001252_mask.png (deflated 60%)
#   adding: dataset/masks/000000000155_mask.png (deflated 71%)
#   adding: dataset/masks/000000000183_mask.png (deflated 89%)
#   adding: dataset/masks/000000000090_mask.png (deflated 40%)
#   adding: dataset/masks/000000000809_mask.png (deflated 57%)
#   adding: dataset/masks/000000001175_mask.png (deflated 58%)
#   adding: dataset/masks/000000000968_mask.png (deflated 42%)
#   adding: dataset/masks/000000000448_mask.png (deflated 43%)
#   adding: dataset/masks/000000000759_mask.png (deflated 66%)
#   adding: dataset/masks/000000000251_mask.png (deflated 45%)
#   adding: dataset/masks/000000001494_mask.png (deflated 43%)
#   adding: dataset/masks/000000000676_mask.png (deflated 57%)
#   adding: dataset/masks/000000000890_mask.png (deflated 71%)
#   adding: dataset/masks/000000001097_mask.png (deflated 59%)
#   adding: dataset/masks/000000000686_mask.png (deflated 63%)
#   adding: dataset/masks/000000000771_mask.png (deflated 55%)
#   adding: dataset/masks/000000001309_mask.png (deflated 66%)
#   adding: dataset/masks/000000001385_mask.png (deflated 75%)
#   adding: dataset/masks/000000000128_mask.png (deflated 64%)
#   adding: dataset/masks/000000000345_mask.png (deflated 64%)
#   adding: dataset/masks/000000000570_mask.png (deflated 61%)
#   adding: dataset/masks/000000000880_mask.png (deflated 90%)
#   adding: dataset/masks/000000000549_mask.png (deflated 52%)
#   adding: dataset/masks/000000000870_mask.png (deflated 71%)
#   adding: dataset/masks/000000000674_mask.png (deflated 91%)
#   adding: dataset/masks/000000000664_mask.png (deflated 50%)
#   adding: dataset/masks/000000000933_mask.png (deflated 80%)
#   adding: dataset/masks/000000000191_mask.png (deflated 59%)
#   adding: dataset/masks/000000000725_mask.png (deflated 54%)
#   adding: dataset/masks/000000000619_mask.png (deflated 52%)
#   adding: dataset/masks/000000001371_mask.png (deflated 91%)
#   adding: dataset/masks/000000001242_mask.png (deflated 56%)
#   adding: dataset/masks/000000001411_mask.png (deflated 89%)
#   adding: dataset/masks/000000000463_mask.png (deflated 52%)
#   adding: dataset/masks/000000001418_mask.png (deflated 90%)
#   adding: dataset/masks/000000001380_mask.png (deflated 57%)
#   adding: dataset/masks/000000000427_mask.png (deflated 88%)
#   adding: dataset/masks/000000001195_mask.png (deflated 92%)
#   adding: dataset/masks/000000000212_mask.png (deflated 58%)
#   adding: dataset/masks/000000001194_mask.png (deflated 73%)
#   adding: dataset/masks/000000000527_mask.png (deflated 90%)
#   adding: dataset/masks/000000000416_mask.png (deflated 66%)
#   adding: dataset/masks/000000000275_mask.png (deflated 66%)
#   adding: dataset/masks/000000001482_mask.png (deflated 52%)
#   adding: dataset/masks/000000001076_mask.png (deflated 49%)
#   adding: dataset/masks/000000001363_mask.png (deflated 47%)
#   adding: dataset/masks/000000001459_mask.png (deflated 88%)
#   adding: dataset/masks/000000001583_mask.png (deflated 67%)
#   adding: dataset/masks/000000000970_mask.png (deflated 59%)
#   adding: dataset/masks/000000001492_mask.png (deflated 61%)
#   adding: dataset/masks/000000000229_mask.png (deflated 72%)
#   adding: dataset/masks/000000000205_mask.png (deflated 60%)
#   adding: dataset/masks/000000000662_mask.png (deflated 55%)
#   adding: dataset/masks/000000001357_mask.png (deflated 89%)
#   adding: dataset/masks/000000000748_mask.png (deflated 50%)
#   adding: dataset/masks/000000000188_mask.png (deflated 55%)
#   adding: dataset/masks/000000000552_mask.png (deflated 55%)
#   adding: dataset/masks/000000001118_mask.png (deflated 81%)
#   adding: dataset/masks/000000000063_mask.png (deflated 48%)
#   adding: dataset/masks/000000000069_mask.png (deflated 50%)
#   adding: dataset/masks/000000000453_mask.png (deflated 62%)
#   adding: dataset/masks/000000001439_mask.png (deflated 49%)
#   adding: dataset/masks/000000000408_mask.png (deflated 39%)
#   adding: dataset/masks/000000001127_mask.png (deflated 90%)
#   adding: dataset/masks/000000000665_mask.png (deflated 47%)
#   adding: dataset/masks/000000000535_mask.png (deflated 68%)
#   adding: dataset/masks/000000001152_mask.png (deflated 89%)
#   adding: dataset/masks/000000001257_mask.png (deflated 60%)
#   adding: dataset/masks/000000001551_mask.png (deflated 45%)
#   adding: dataset/masks/000000001192_mask.png (deflated 28%)
#   adding: dataset/masks/000000001172_mask.png (deflated 77%)
#   adding: dataset/masks/000000001251_mask.png (deflated 59%)
#   adding: dataset/masks/000000000311_mask.png (deflated 50%)
#   adding: dataset/masks/000000001410_mask.png (deflated 55%)
#   adding: dataset/masks/000000000178_mask.png (deflated 92%)
#   adding: dataset/masks/000000001362_mask.png (deflated 45%)
#   adding: dataset/masks/000000000108_mask.png (deflated 54%)
#   adding: dataset/masks/000000000276_mask.png (deflated 64%)
#   adding: dataset/masks/000000000001_mask.png (deflated 60%)
#   adding: dataset/masks/000000000953_mask.png (deflated 46%)
